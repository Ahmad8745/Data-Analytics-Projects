# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df=pd.read_csv("tips.csv")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.total_bill.sum() #or
#sum(df.total_bill)
# Out:
# 4827.77

# %%
df.tip.sum()
# Out:
# 731.5799999999999

# %%
#to check is there any missing value or not
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df.day
# Out:
# 0       Sun
# 1       Sun
# 2       Sun
# 3       Sun
# 4       Sun
#        ...
# 239     Sat
# 240     Sat
# 241     Sat
# 242     Sat
# 243    Thur
# Name: day, Length: 244, dtype: object

# %%
df.day.value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
df.day.value_counts().index
# Out:
# Index(['Sat', 'Sun', 'Thur', 'Fri'], dtype='object')

# %%
df.day.value_counts().values
# Out:
# array([87, 76, 62, 19], dtype=int64)

# %%
# for showing graphically day wise open
cont=[]
for i,j in zip(df.day.value_counts().index,df.day.value_counts().values):
    a=(i,j)
    cont.append(a)
plt.pie(x=df.day.value_counts().values,labels=cont)
plt.show()

# %%
df.time.value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
df.smoker
# Out:
# 0       No
# 1       No
# 2       No
# 3       No
# 4       No
#       ...
# 239     No
# 240    Yes
# 241    Yes
# 242     No
# 243     No
# Name: smoker, Length: 244, dtype: object

# %%
df.smoker.value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
df.sex
# Out:
# 0      Female
# 1        Male
# 2        Male
# 3        Male
# 4      Female
#         ...
# 239      Male
# 240    Female
# 241      Male
# 242      Male
# 243    Female
# Name: sex, Length: 244, dtype: object

# %%
df.sex.value_counts()
plt.bar(x=df.sex.value_counts().index,height=df.sex.value_counts().values,color=["blue","green"])
# Out:
# <BarContainer object of 2 artists>

# %%
df.total_bill
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
df.total_bill.min()
# Out:
# 3.07

# %%
df.total_bill.max()
# Out:
# 50.81

# %%
df.tip
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
df.tip.min()
# Out:
# 1.0

# %%
df.tip.max()
# Out:
# 10.0

# %%
# graphical representation of total_bill and tip by male and female
sn.scatterplot(x=df.total_bill,y=df.tip,style=df.sex,hue=df.day)
plt.show()

# %%
df.size
# Out:
# 1708

# %%
np.sum(df["size"])
# Out:
# 627

# %%
# now we will use conditional formating
df[df.sex=="Male"].shape
# Out:
# (157, 7)

# %%
# Male=157

# %%
df[(df.sex=="Male") & (df.smoker=="Yes")].shape
# Out:
# (60, 7)

# %%
(60/157)*100
# Out:
# 38.21656050955414

# %%
df[df.sex=="Female"]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# 16        10.33  1.67  Female     No   Sun  Dinner     3
# ..          ...   ...     ...    ...   ...     ...   ...
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [87 rows x 7 columns]

# %%
df[df.sex=="Female"].shape
# Out:
# (87, 7)

# %%
df[(df.sex=="Female") & (df.smoker=="Yes")]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1
# 72        26.86  3.14  Female    Yes   Sat  Dinner     2
# 73        25.28  5.00  Female    Yes   Sat  Dinner     2
# 92         5.75  1.00  Female    Yes   Fri  Dinner     2
# 93        16.32  4.30  Female    Yes   Fri  Dinner     2
# 100       11.35  2.50  Female    Yes   Fri  Dinner     2
# 101       15.38  3.00  Female    Yes   Fri  Dinner     2
# 102       44.30  2.50  Female    Yes   Sat  Dinner     3
# 103       22.42  3.48  Female    Yes   Sat  Dinner     2
# 109       14.31  4.00  Female    Yes   Sat  Dinner     2
# 164       17.51  3.00  Female    Yes   Sun  Dinner     2
# 168       10.59  1.61  Female    Yes   Sat  Dinner     2
# 169       10.63  2.00  Female    Yes   Sat  Dinner     2
# 178        9.60  4.00  Female    Yes   Sun  Dinner     2
# 186       20.90  3.50  Female    Yes   Sun  Dinner     3
# ...

# %%
df[(df.sex=="Female") & (df.smoker=="Yes")].shape
# Out:
# (33, 7)

# %%
(33/87)*100
# Out:
# 37.93103448275862

# %% [markdown]
# # Report 1:-
# - Total % of male smoker is 38.21656050955414 %
# - Total % of female smoker is 37.931034482758 %

# %%
df.time.value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
df[(df.day=="Sat") & (df.sex=="Female")]
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 21        20.29  2.75  Female     No  Sat  Dinner     2
# 22        15.77  2.23  Female     No  Sat  Dinner     2
# 29        19.65  3.00  Female     No  Sat  Dinner     2
# 32        15.06  3.00  Female     No  Sat  Dinner     2
# 33        20.69  2.45  Female     No  Sat  Dinner     4
# 37        16.93  3.07  Female     No  Sat  Dinner     3
# 57        26.41  1.50  Female     No  Sat  Dinner     2
# 66        16.45  2.47  Female     No  Sat  Dinner     2
# 67         3.07  1.00  Female    Yes  Sat  Dinner     1
# 71        17.07  3.00  Female     No  Sat  Dinner     3
# 72        26.86  3.14  Female    Yes  Sat  Dinner     2
# 73        25.28  5.00  Female    Yes  Sat  Dinner     2
# 74        14.73  2.20  Female     No  Sat  Dinner     2
# 102       44.30  2.50  Female    Yes  Sat  Dinner     3
# 103       22.42  3.48  Female    Yes  Sat  Dinner     2
# 104       20.92  4.08  Female     No  Sat  Dinner     2
# ...

# %%
df1=df[(df.day=="Sat") & (df.sex=="Female")]
df1
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 21        20.29  2.75  Female     No  Sat  Dinner     2
# 22        15.77  2.23  Female     No  Sat  Dinner     2
# 29        19.65  3.00  Female     No  Sat  Dinner     2
# 32        15.06  3.00  Female     No  Sat  Dinner     2
# 33        20.69  2.45  Female     No  Sat  Dinner     4
# 37        16.93  3.07  Female     No  Sat  Dinner     3
# 57        26.41  1.50  Female     No  Sat  Dinner     2
# 66        16.45  2.47  Female     No  Sat  Dinner     2
# 67         3.07  1.00  Female    Yes  Sat  Dinner     1
# 71        17.07  3.00  Female     No  Sat  Dinner     3
# 72        26.86  3.14  Female    Yes  Sat  Dinner     2
# 73        25.28  5.00  Female    Yes  Sat  Dinner     2
# 74        14.73  2.20  Female     No  Sat  Dinner     2
# 102       44.30  2.50  Female    Yes  Sat  Dinner     3
# 103       22.42  3.48  Female    Yes  Sat  Dinner     2
# 104       20.92  4.08  Female     No  Sat  Dinner     2
# ...

# %%
df1.shape
# Out:
# (28, 7)

# %%
sum(df1.total_bill)
# Out:
# 551.0499999999998

# %%
df2=df[(df.sex=="Male") & (df.day=="Sat")]
df2
# Out:
#      total_bill    tip   sex smoker  day    time  size
# 19        20.65   3.35  Male     No  Sat  Dinner     3
# 20        17.92   4.08  Male     No  Sat  Dinner     2
# 23        39.42   7.58  Male     No  Sat  Dinner     4
# 24        19.82   3.18  Male     No  Sat  Dinner     2
# 25        17.81   2.34  Male     No  Sat  Dinner     4
# 26        13.37   2.00  Male     No  Sat  Dinner     2
# 27        12.69   2.00  Male     No  Sat  Dinner     2
# 28        21.70   4.30  Male     No  Sat  Dinner     2
# 30         9.55   1.45  Male     No  Sat  Dinner     2
# 31        18.35   2.50  Male     No  Sat  Dinner     4
# 34        17.78   3.27  Male     No  Sat  Dinner     2
# 35        24.06   3.60  Male     No  Sat  Dinner     3
# 36        16.31   2.00  Male     No  Sat  Dinner     3
# 38        18.69   2.31  Male     No  Sat  Dinner     3
# 39        31.27   5.00  Male     No  Sat  Dinner     3
# 40        16.04   2.24  Male     No  Sat  Dinner     3
# ...

# %%
df2.shape
# Out:
# (59, 7)

# %%
df2.total_bill
# Out:
# 19     20.65
# 20     17.92
# 23     39.42
# 24     19.82
# 25     17.81
# 26     13.37
# 27     12.69
# 28     21.70
# 30      9.55
# 31     18.35
# 34     17.78
# 35     24.06
# 36     16.31
# 38     18.69
# 39     31.27
# 40     16.04
# 56     38.01
# 58     11.24
# 59     48.27
# 60     20.29
# 61     13.81
# 62     11.02
# 63     18.29
# 64     17.59
# 65     20.08
# 68     20.23
# 69     15.01
# 70     12.02
# 75     10.51
# 76     17.92
# 105    15.36
# 106    20.49
# 107    25.21
# 108    18.24
# 110    14.00
# 170    50.81
# 171    15.81
# 206    26.59
# 207    38.73
# 208    24.27
# 210    30.06
# 211    25.89
# 212    48.33
# 216    28.15
# 217    11.59
# 218     7.74
# 227    20.45
# 228    13.28
# 230    24.01
# 231    15.69
# 232    11.61
# 233    10.77
# 234    15.53
# 235    10.07
# 236    12.60
# 237    32.83
# 239    29.03
# 241    22.67
# 242    17.82
# Name: total_bill, dtype: float64

# %%
df2.total_bill.sum()
# Out:
# 1227.35

# %%
df2.total_bill.mean()
# Out:
# 20.80254237288135

# %%
df1.total_bill.mean()
# Out:
# 19.680357142857137

# %% [markdown]
# # Report 2:-
# - Average payment of man on saturday is $20.802542
#
# - Average payment of man on saturday is $19.680357

# %%
# motive to find male and female average payment according to time

# %%
df[(df.time=="Lunch") & (df.sex=="Male") & (df.day=="Sat")]
# Out:
# Empty DataFrame
# Columns: [total_bill, tip, sex, smoker, day, time, size]
# Index: []

# %%
df[(df.time=="Lunch") & (df.sex=="Female") & (df.day=="Sat")]
# Out:
# Empty DataFrame
# Columns: [total_bill, tip, sex, smoker, day, time, size]
# Index: []

# %%
df[(df.time=="Dinner") & (df.sex=="Female") & (df.day=="Sat")].shape
# Out:
# (28, 7)

# %%
df[(df.time=="Dinner") & (df.sex=="Male") & (df.day=="Sat")].shape
# Out:
# (59, 7)

# %% [markdown]
# # Report 3:-
# - On saturday restaurant was not open on Lunch time

# %%
df[(df.time=="Dinner") & (df.sex=="Female") & (df.day=="Sun")].total_bill.mean()
# Out:
# 19.87222222222222

# %%
df[(df.time=="Dinner") & (df.sex=="Male") & (df.day=="Sun")].total_bill.mean()
# Out:
# 21.887241379310346

# %% [markdown]
# ### Use of group by for analysis

# %%
df.total_bill.groupby(by=[df.sex,df.day,df.time]).agg(["sum","min","max","mean","count"])
# Out:
#                         sum    min    max       mean  count
# sex    day  time
# Female Fri  Dinner    71.55   5.75  22.75  14.310000      5
#             Lunch     55.76  10.09  16.27  13.940000      4
#        Sat  Dinner   551.05   3.07  44.30  19.680357     28
#        Sun  Dinner   357.70   9.60  35.26  19.872222     18
#        Thur Dinner    18.78  18.78  18.78  18.780000      1
#             Lunch    516.11   8.35  43.11  16.648710     31
# Male   Fri  Dinner   164.41  12.03  40.17  23.487143      7
#             Lunch     34.16   8.58  13.42  11.386667      3
#        Sat  Dinner  1227.35   7.74  50.81  20.802542     59
#        Sun  Dinner  1269.46   7.25  48.17  21.887241     58
#        Thur Lunch    561.44   7.51  41.19  18.714667     30

# %%
df.total_bill.groupby(by=[df.sex,df.day,df.time,df.smoker]).agg(["sum","min","max","mean","count"])
# Out:
#                               sum    min    max       mean  count
# sex    day  time   smoker
# Female Fri  Dinner No       22.75  22.75  22.75  22.750000      1
#                    Yes      48.80   5.75  16.32  12.200000      4
#             Lunch  No       15.98  15.98  15.98  15.980000      1
#                    Yes      39.78  10.09  16.27  13.260000      3
#        Sat  Dinner No      247.05   7.25  35.83  19.003846     13
#                    Yes     304.00   3.07  44.30  20.266667     15
#        Sun  Dinner No      291.54  10.29  35.26  20.824286     14
#                    Yes      66.16   9.60  20.90  16.540000      4
#        Thur Dinner No       18.78  18.78  18.78  18.780000      1
#             Lunch  No      381.58   8.35  34.83  15.899167     24
#                    Yes     134.53  12.74  43.11  19.218571      7
# Male   Fri  Dinner No       34.95  12.46  22.49  17.475000      2
#                    Yes     129.46  12.03  40.17  25.892000      5
# ...

# %%
df.tip.groupby(by=[df.sex,df.day,df.time,df.smoker]).agg(["sum","min","max","mean","count"])
# Out:
#                               sum   min    max      mean  count
# sex    day  time   smoker
# Female Fri  Dinner No        3.25  3.25   3.25  3.250000      1
#                    Yes      10.80  1.00   4.30  2.700000      4
#             Lunch  No        3.00  3.00   3.00  3.000000      1
#                    Yes       7.98  2.00   3.48  2.660000      3
#        Sat  Dinner No       35.42  1.00   4.67  2.724615     13
#                    Yes      43.03  1.00   6.50  2.868667     15
#        Sun  Dinner No       46.61  1.01   5.20  3.329286     14
#                    Yes      14.00  3.00   4.00  3.500000      4
#        Thur Dinner No        3.00  3.00   3.00  3.000000      1
#             Lunch  No       58.49  1.25   5.17  2.437083     24
#                    Yes      20.93  2.00   5.00  2.990000      7
# Male   Fri  Dinner No        5.00  1.50   3.50  2.500000      2
#                    Yes      16.23  1.50   4.73  3.246000      5
# ...

# %% [markdown]
# ### for showing how many customers are coming on day and time wise

# %%
sn.countplot(x=df.day,order=["Thur","Fri","Sat","Sun"],hue=df.time)
plt.show()
